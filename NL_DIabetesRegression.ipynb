# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
train_df = pd.read_csv("/content/train.csv")
test_df = pd.read_csv("/content/test.csv")

# %%
train_df
# Out:
#      Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0                M  35.0               120.0                78.0
# 1                M  29.0               100.0                66.0
# 2                M  38.0               110.0                78.0
# 3                M  27.0               110.0                65.0
# 4                M  36.0               100.0                70.0
# ...            ...   ...                 ...                 ...
# 1066             F  33.0               120.0                80.0
# 1067             M  34.0               110.0                70.0
# 1068             F  39.0               120.0                70.0
# 1069             M  30.0                90.0                60.0
# 1070             M  34.0               110.0                70.0
#
#       Tinggi badan (cm)  Berat badan (kg)  IMT (kg/m2)  Lingkar perut (cm)  \
# 0                 164.0             47.60        18.00                65.0
# ...

# %%
test_df
# Out:
#     Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0               M  25.0               110.0                80.0
# 1               M  30.0               120.0                90.0
# 2               M  25.0               122.0                82.0
# 3               M  25.0               120.0                80.0
# 4               M  24.0               120.0                80.0
# ..            ...   ...                 ...                 ...
# 263             M  23.0               120.0                80.0
# 264             M  29.0               100.0                60.0
# 265             M  27.0               100.0                70.0
# 266             F  38.0               100.0                70.0
# 267             F  28.0               100.0                66.0
#
#      Tinggi badan (cm)  Berat badan (kg)  IMT (kg/m2)  Lingkar perut (cm)  \
# 0                165.0             62.50        23.20                80.0
# ...

# %%
train_df['Jenis Kelamin'] = train_df['Jenis Kelamin'].replace({'M': 0, 'F': 1})
train_df
# Out:
# /tmp/ipython-input-7-1113431205.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['Jenis Kelamin'] = train_df['Jenis Kelamin'].replace({'M': 0, 'F': 1})
#       Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0                 0  35.0               120.0                78.0
# 1                 0  29.0               100.0                66.0
# 2                 0  38.0               110.0                78.0
# 3                 0  27.0               110.0                65.0
# 4                 0  36.0               100.0                70.0
# ...             ...   ...                 ...                 ...
# 1066              1  33.0               120.0                80.0
# ...

# %%
train_df = train_df.drop(columns=['Tempat lahir'])
train_df
# Out:
#       Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0                 0  35.0               120.0                78.0
# 1                 0  29.0               100.0                66.0
# 2                 0  38.0               110.0                78.0
# 3                 0  27.0               110.0                65.0
# 4                 0  36.0               100.0                70.0
# ...             ...   ...                 ...                 ...
# 1066              1  33.0               120.0                80.0
# 1067              0  34.0               110.0                70.0
# 1068              1  39.0               120.0                70.0
# 1069              0  30.0                90.0                60.0
# 1070              0  34.0               110.0                70.0
#
#       Tinggi badan (cm)  Berat badan (kg)  IMT (kg/m2)  Lingkar perut (cm)  \
# 0                 164.0             47.60        18.00                65.0
# ...

# %%
test_id_for_submission = test_df['id']
test_id_for_submission
# Out:
# 0       394
# 1       881
# 2       358
# 3       367
# 4       259
#        ...
# 263     109
# 264     818
# 265     538
# 266    1285
# 267     714
# Name: id, Length: 268, dtype: int64

# %%
test_df['Jenis Kelamin'] = test_df['Jenis Kelamin'].replace({'M': 0, 'F': 1})
test_df = test_df.drop(columns=['Tempat lahir', 'id'])
test_df
# Out:
# /tmp/ipython-input-10-2062299161.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df['Jenis Kelamin'] = test_df['Jenis Kelamin'].replace({'M': 0, 'F': 1})
#      Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0                0  25.0               110.0                80.0
# 1                0  30.0               120.0                90.0
# 2                0  25.0               122.0                82.0
# 3                0  25.0               120.0                80.0
# 4                0  24.0               120.0                80.0
# ..             ...   ...                 ...                 ...
# 263              0  23.0               120.0                80.0
# ...

# %% [markdown]
# UNTUK DATASET TRAIN

# %% [markdown]
# Train Test Split

# %%
y_train = train_df['Cholesterol Total (mg/dL)']
x_train = train_df.drop(columns=['Cholesterol Total (mg/dL)'])

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
train_prediction = model.predict(x_train)
error = mean_absolute_error(y_train, train_prediction)
rmse = np.sqrt(mean_squared_error(y_train, train_prediction))

# %%
error
# Out:
# 11.614045547385013

# %%
rmse
# Out:
# np.float64(19.962115593928086)

# %% [markdown]
# UNTUK DATASET TEST

# %%
x_train
# Out:
#       Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0                 0  35.0               120.0                78.0
# 1                 0  29.0               100.0                66.0
# 2                 0  38.0               110.0                78.0
# 3                 0  27.0               110.0                65.0
# 4                 0  36.0               100.0                70.0
# ...             ...   ...                 ...                 ...
# 1066              1  33.0               120.0                80.0
# 1067              0  34.0               110.0                70.0
# 1068              1  39.0               120.0                70.0
# 1069              0  30.0                90.0                60.0
# 1070              0  34.0               110.0                70.0
#
#       Tinggi badan (cm)  Berat badan (kg)  IMT (kg/m2)  Lingkar perut (cm)  \
# 0                 164.0             47.60        18.00                65.0
# ...

# %%
test_df
# Out:
#      Jenis Kelamin  Usia  Tekanan darah  (S)  Tekanan darah  (D)  \
# 0                0  25.0               110.0                80.0
# 1                0  30.0               120.0                90.0
# 2                0  25.0               122.0                82.0
# 3                0  25.0               120.0                80.0
# 4                0  24.0               120.0                80.0
# ..             ...   ...                 ...                 ...
# 263              0  23.0               120.0                80.0
# 264              0  29.0               100.0                60.0
# 265              0  27.0               100.0                70.0
# 266              1  38.0               100.0                70.0
# 267              1  28.0               100.0                66.0
#
#      Tinggi badan (cm)  Berat badan (kg)  IMT (kg/m2)  Lingkar perut (cm)  \
# 0                165.0             62.50        23.20                80.0
# ...

# %%
test_predict = model.predict(test_df)
test_predict
# Out:
# array([185.52383812, 185.67451253, 188.0736067 , 187.10016696,
#        188.57220406, 182.37050467, 188.13298834, 180.98537769,
#        183.08695122, 176.10004118, 188.44511669, 191.70064428,
#        194.43392374, 195.33400373, 173.9486742 , 175.85537585,
#        176.36869928, 190.03782643, 185.62870688, 192.23619034,
#        191.17920037, 186.90209256, 190.96812356, 183.6920195 ,
#        185.83571155, 186.20730127, 186.97552184, 172.93776808,
#        186.05273304, 187.21636655, 182.89282872, 195.53374153,
#        186.99332567, 176.12794838, 182.41230959, 187.48663624,
#        185.87214983, 181.54165026, 191.2071288 , 188.45023486,
#        190.70032635, 190.18978838, 189.71529976, 191.77046281,
#        179.36145274, 184.15086839, 186.17050124, 185.83027997,
#        197.80049215, 189.67086588, 200.29964537, 176.61911757,
#        182.21650594, 185.20577954, 192.0719835 , 188.63695555,
#        185.82988852, 181.49778467, 185.27882194, 190.81800045,
# ...

# %%
submission_df = pd.DataFrame({
    'id': test_id_for_submission,
    'Cholesterol Total (mg/dL)': test_predict
})

submission_df.to_csv('submission.csv', index=False)
print("File submission.csv berhasil dibuat!")
# Out:
# File submission.csv berhasil dibuat!

# %%
submission_df = pd.read_csv("/content/submission.csv")
submission_df
# Out:
#        id  Cholesterol Total (mg/dL)
# 0     394                 185.523838
# 1     881                 185.674513
# 2     358                 188.073607
# 3     367                 187.100167
# 4     259                 188.572204
# ..    ...                        ...
# 263   109                 190.907770
# 264   818                 182.595260
# 265   538                 182.550166
# 266  1285                 177.895783
# 267   714                 185.665828
#
# [268 rows x 2 columns]
